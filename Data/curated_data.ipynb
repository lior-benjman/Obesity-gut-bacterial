# %%
install.packages("BiocManager", repos = "https://cran.rstudio.com")
# Out:
#   There is a binary version available but the source version is later:
#              binary  source needs_compilation
# BiocManager 1.30.20 1.30.27             FALSE
# installing the source package 'BiocManager'

# %%
BiocManager::install("curatedMetagenomicData", update = FALSE, ask = FALSE)
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.14 (BiocManager 1.30.27), R 4.1.3 (2022-03-10)
#
# Installing package(s) 'curatedMetagenomicData'
#    package 'curatedMetagenomicData' is available as a source package but not as a binary
# Warning message:
# "package 'curatedMetagenomicData' is not available as a binary package for Bioconductor version '3.14'
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages"
# Old packages: 'ape', 'askpass', 'bit', 'bit64', 'bitops', 'cachem', 'cli',
#   'cluster', 'commonmark', 'crayon', 'curl', 'digest', 'dplyr', 'evaluate',
#   'fansi', 'farver', 'filelock', 'fs', 'ggplot2', 'ggrepel', 'glue',
# ...

# %%
library(curatedMetagenomicData)
# Out:
# Error in library(curatedMetagenomicData): there is no package called 'curatedMetagenomicData'
# Traceback:
#
# 1. library(curatedMetagenomicData)

# %%
find.package("curatedMetagenomicData")
# Out:
# Error in find.package("curatedMetagenomicData"): there is no package called 'curatedMetagenomicData'
# Traceback:
#
# 1. find.package("curatedMetagenomicData")
